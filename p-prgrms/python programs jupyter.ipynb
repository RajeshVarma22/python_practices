# %%
s=input("Enter Some String:")
i=len(s)-1
target=''
while i>=0:
    target=target+s[i]
    i=i-1
print(target)
# Out:
# Enter Some String:rajesh
# hsejar

# %%
s=input("Enter Some String:")
i=len(s)-1
target=''
while i>=0:
    target=target+s[i]
    i=i-1
print(target)
# Out:
# Enter Some String:my name is rajesh varma
# amrav hsejar si eman ym

# %%
n=int(input("enter a number"))
for i in range(n):
    print(i)
# Out:
# enter a number5
# 0
# 1
# 2
# 3
# 4

# %%
n=int(input("enter a number"))
for i in range(n):
    print(n)
# Out:
# enter a number5
# 5
# 5
# 5
# 5
# 5

# %%
n=int(input("enter a number"))
for i in range(n):
    print(i*'*')#here i =0 and then i*'*' willbe printed as 0 *'s in firstline
# Out:
# enter a number5
#
# *
# **
# ***
# ****

# %%
n=int(input("enter a number"))
i=1#it doesn't work
for i in range(n):
    print(i*'*')
# Out:
# enter a number5
#
# *
# **
# ***
# ****

# %%
n=int(input("enter a number"))
i=1
for i in range(i,n+1):
    print(i*'*')
# Out:
# enter a number5
# *
# **
# ***
# ****
# *****

# %%
n=int(input("enter a number"))
i=1
for i in range(i,n):
    print(i**'*')
# Out:
# enter a number2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15892/2109209751.py in <module>
#       2 i=1
#       3 for i in range(i,n):
# ----> 4     print(i**'*')
#
# TypeError: unsupported operand type(s) for ** or pow(): 'int' and 'str'

# %%
n=int(input("enter a number"))
i=1
for i in range(i,n):
    print(i**2)
# Out:
# enter a number5
# 1
# 4
# 9
# 16

# %%
n=int(input("enter a number"))
i=1
for i in range(i,n):
    print(i*"*")
# Out:
# enter a number5
# *
# **
# ***
# ****

# %%
n=int(input("enter a number"))
i=1
for i in range(i,n):
    print(i*" * ")
# Out:
# enter a number5
#  *
#  *  *
#  *  *  *
#  *  *  *  *

# %%
n=int(input("enter a number"))
for i in range(1,n):
    for j in range(i,n):
        print("*")
# Out:
# enter a number5
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
n=int(input("enter a number"))
for i in range(1,n+1):
    for j in range(i,n+1):
        print("*",end='')
    print()
# Out:
# enter a number5
# *****
# ****
# ***
# **
# *

# %%
n=int(input("enter a number"))
for i in range(1,n+1):
    for j in range(i,n+1):
        print(" *",end='')
    print()
# Out:
# enter a number5
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *

# %%
n=int(input("enter a number"))
for i in range(1,n+1):
    for j in range(i):
        print("*",end='')
    print()
# Out:
# enter a number5
# *
# **
# ***
# ****
# *****

# %%
n=int(input("enter a number"))
for i in range(1,n+1):
    for j in range(n-i):
        print("*",end='')
    print()
# Out:
# enter a number5
# ****
# ***
# **
# *
